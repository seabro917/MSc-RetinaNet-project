# %%
from tensorboard.backend.event_processing import event_accumulator
import matplotlib.pyplot as plt
import numpy as np

tensorboard_path = r"D:\Studying\RetinaNet_snapshots\12_06_2020_anchor_opt\logs"
val_name_1 = 'val_regression_loss'
val_name_2 = 'val_classification_loss'
ea = event_accumulator.EventAccumulator(tensorboard_path)
ea.Reload()
print(ea.scalars.Keys())
val_1 = ea.scalars.Items(val_name_1)
val_2 = ea.scalars.Items(val_name_2)

plt.figure()
steps = [i.step for i in val_1]
val_regression = [j.value for j in val_1]
val_classification = [x.value for x in val_2]
# print(val_regression)
# print(val_classification)
plt.plot(steps, np.array(val_regression) + np.array(val_classification))
plt.xlabel('step')
plt.ylabel(val_name_1)
plt.show()
# Out:
# ['mAP', 'val_loss', 'val_regression_loss', 'val_classification_loss', 'loss', 'regression_loss', 'classification_loss', 'lr']

# %%
# Plot two events result for comparison
# Test for smoothed plot here

from tensorboard.backend.event_processing import event_accumulator
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline

tensorboard_path_1 = r"D:\Studying\RetinaNet_snapshots\20_06_2020_focal_config\logs"
tensorboard_path_2 = r"D:\Studying\RetinaNet_snapshots\12_06_2020_no_random_transform\logs"
tensorboard_path_3 = r"D:\Studying\RetinaNet_snapshots\18_06_2020_focal_config\logs"
# tensorboard_path_4 = r"D:\Studying\RetinaNet_snapshots\22_06_2020_focal_config\logs"

val_name_1 = 'val_regression_loss'
val_name_2 = 'val_classification_loss'
ea_1 = event_accumulator.EventAccumulator(tensorboard_path_1)
ea_1.Reload()
ea_2 = event_accumulator.EventAccumulator(tensorboard_path_2)
ea_2.Reload()
ea_3 = event_accumulator.EventAccumulator(tensorboard_path_3)
ea_3.Reload()
# ea_4 = event_accumulator.EventAccumulator(tensorboard_path_4)
# ea_4.Reload()
# print(ea.scalars.Keys())

# First event object
val_1_1 = ea_1.scalars.Items(val_name_1)
val_2_1 = ea_1.scalars.Items(val_name_2)
# Second event object
val_1_2 = ea_2.scalars.Items(val_name_1)
val_2_2 = ea_2.scalars.Items(val_name_2)
# Third event object
val_1_3 = ea_3.scalars.Items(val_name_1)
val_2_3 = ea_3.scalars.Items(val_name_2)
# Fourth event object
# val_1_4 = ea_4.scalars.Items(val_name_1)
# val_2_4 = ea_4.scalars.Items(val_name_2)

plt.figure()
steps = [i.step for i in val_1_1]
val_regression_1 = [j.value for j in val_1_1]
val_classification_1 = [x.value for x in val_2_1]
final_val_loss_1 = np.array(val_regression_1) + np.array(val_classification_1)


val_regression_2 = [a.value for a in val_1_2]
val_classification_2 = [b.value for b in val_2_2]
final_val_loss_2 = np.array(val_regression_2) + np.array(val_classification_2)

val_regression_3 = [a.value for a in val_1_3]
val_classification_3 = [b.value for b in val_2_3]
final_val_loss_3 = np.array(val_regression_3) + np.array(val_classification_3)

# val_regression_4 = [a.value for a in val_1_4]
# val_classification_4 = [b.value for b in val_2_4]
# final_val_loss_4 = np.array(val_regression_4) + np.array(val_classification_4)


p1, = plt.plot(steps, final_val_loss_1)
p2, = plt.plot(steps, final_val_loss_2)
p3, = plt.plot(steps, final_val_loss_3)
# p4, = plt.plot(steps, final_val_loss_4)

plt.legend(handles=[p1,p2,p3],labels=['gamma=3.5, alpha=0.95','gamma=5, alpha=0.95','gamma=6.5, alpha=0.95'],loc='best')
plt.xlabel('Epoch')
plt.ylabel('Validation loss')
plt.grid()
plt.savefig('test.pdf', dpi=500, bbox_inches = 'tight')
plt.show()

# %%
# Plot two events result for comparison
# Test for smoothed plot here

from tensorboard.backend.event_processing import event_accumulator
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline


tensorboard_path_1 = r"D:\Studying\RetinaNet_snapshots\12_06_2020_no_random_transform\logs"
tensorboard_path_2 = r"D:\Studying\RetinaNet_snapshots\23_06_2020_focal_config\logs"
tensorboard_path_3 = r"D:\Studying\RetinaNet_snapshots\22_06_2020_focal_config\logs"

val_name_1 = 'val_regression_loss'
val_name_2 = 'val_classification_loss'
ea_1 = event_accumulator.EventAccumulator(tensorboard_path_1)
ea_1.Reload()
ea_2 = event_accumulator.EventAccumulator(tensorboard_path_2)
ea_2.Reload()
ea_3 = event_accumulator.EventAccumulator(tensorboard_path_3)
ea_3.Reload()
# ea_4 = event_accumulator.EventAccumulator(tensorboard_path_4)
# ea_4.Reload()
# print(ea.scalars.Keys())

# First event object
val_1_1 = ea_1.scalars.Items(val_name_1)
val_2_1 = ea_1.scalars.Items(val_name_2)
# Second event object
val_1_2 = ea_2.scalars.Items(val_name_1)
val_2_2 = ea_2.scalars.Items(val_name_2)
# Third event object
val_1_3 = ea_3.scalars.Items(val_name_1)
val_2_3 = ea_3.scalars.Items(val_name_2)
# Fourth event object
# val_1_4 = ea_4.scalars.Items(val_name_1)
# val_2_4 = ea_4.scalars.Items(val_name_2)

plt.figure()
steps = [i.step for i in val_1_1]
val_regression_1 = [j.value for j in val_1_1]
val_classification_1 = [x.value for x in val_2_1]
final_val_loss_1 = np.array(val_regression_1) + np.array(val_classification_1)


val_regression_2 = [a.value for a in val_1_2]
val_classification_2 = [b.value for b in val_2_2]
final_val_loss_2 = np.array(val_regression_2) + np.array(val_classification_2)

val_regression_3 = [a.value for a in val_1_3]
val_classification_3 = [b.value for b in val_2_3]
final_val_loss_3 = np.array(val_regression_3) + np.array(val_classification_3)

# val_regression_4 = [a.value for a in val_1_4]
# val_classification_4 = [b.value for b in val_2_4]
# final_val_loss_4 = np.array(val_regression_4) + np.array(val_classification_4)


p1, = plt.plot(steps, final_val_loss_1)
p2, = plt.plot(steps, final_val_loss_2)
p3, = plt.plot(steps, final_val_loss_3)
# p4, = plt.plot(steps, final_val_loss_4)

plt.legend(handles=[p1,p2,p3],labels=['gamma=5, alpha=0.95','gamma=5, alpha=0.999','gamma=5, alpha=0.9999'],loc='best')
plt.xlabel('Epoch')
plt.ylabel('Validation loss')
plt.grid()
plt.savefig('test.pdf', dpi=500, bbox_inches = 'tight')
plt.show()

# %%
# Plot two events result for comparison
# Test for smoothed plot here

from tensorboard.backend.event_processing import event_accumulator
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline

tensorboard_path_1 = r"D:\Studying\RetinaNet_snapshots\12_06_2020_no_random_transform\logs"
tensorboard_path_2 = r"D:\Studying\RetinaNet_snapshots\18_06_2020_focal_config\logs"
tensorboard_path_3 = r"D:\Studying\RetinaNet_snapshots\20_06_2020_focal_config\logs"
tensorboard_path_4 = r"D:\Studying\RetinaNet_snapshots\22_06_2020_focal_config\logs"

val_name_1 = 'val_regression_loss'
val_name_2 = 'val_classification_loss'
ea_1 = event_accumulator.EventAccumulator(tensorboard_path_1)
ea_1.Reload()
ea_2 = event_accumulator.EventAccumulator(tensorboard_path_2)
ea_2.Reload()
ea_3 = event_accumulator.EventAccumulator(tensorboard_path_3)
ea_3.Reload()
ea_4 = event_accumulator.EventAccumulator(tensorboard_path_4)
ea_4.Reload()
# print(ea.scalars.Keys())

# First event object
val_1_1 = ea_1.scalars.Items(val_name_1)
val_2_1 = ea_1.scalars.Items(val_name_2)
# Second event object
val_1_2 = ea_2.scalars.Items(val_name_1)
val_2_2 = ea_2.scalars.Items(val_name_2)
# Third event object
val_1_3 = ea_3.scalars.Items(val_name_1)
val_2_3 = ea_3.scalars.Items(val_name_2)
# Fourth event object
val_1_4 = ea_4.scalars.Items(val_name_1)
val_2_4 = ea_4.scalars.Items(val_name_2)

plt.figure()
steps = [i.step for i in val_1_1]
val_regression_1 = [j.value for j in val_1_1]
val_classification_1 = [x.value for x in val_2_1]
final_val_loss_1 = np.array(val_regression_1) + np.array(val_classification_1)


val_regression_2 = [a.value for a in val_1_2]
val_classification_2 = [b.value for b in val_2_2]
final_val_loss_2 = np.array(val_regression_2) + np.array(val_classification_2)

val_regression_3 = [a.value for a in val_1_3]
val_classification_3 = [b.value for b in val_2_3]
final_val_loss_3 = np.array(val_regression_3) + np.array(val_classification_3)

val_regression_4 = [a.value for a in val_1_4]
val_classification_4 = [b.value for b in val_2_4]
final_val_loss_4 = np.array(val_regression_4) + np.array(val_classification_4)

# Used for smoothed plot
xnew = np.linspace(0,39,300)

smoothed_val_loss_1 = make_interp_spline(steps, final_val_loss_1)(xnew)
smoothed_val_loss_2 = make_interp_spline(steps, final_val_loss_2)(xnew)
smoothed_val_loss_3 = make_interp_spline(steps, final_val_loss_3)(xnew)
smoothed_val_loss_4 = make_interp_spline(steps, final_val_loss_4)(xnew)

# print(val_regression)
# print(val_classification)


# plt.plot(xnew, smoothed_val_loss_1,'g--')
# plt.plot(xnew, smoothed_val_loss_2,'b^')
# plt.plot(xnew, smoothed_val_loss_3,'mh')
# plt.plot(xnew, smoothed_val_loss_4,'rs')

plt.plot(xnew, smoothed_val_loss_1)
plt.plot(xnew, smoothed_val_loss_2)
plt.plot(xnew, smoothed_val_loss_3)
plt.plot(xnew, smoothed_val_loss_4)
plt.xlabel('step')
plt.ylabel(val_name_1)
plt.show()

# %%
# Same alpha, different gamma 
from tensorboard.backend.event_processing import event_accumulator
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline

tensorboard_path_1 = r"D:\Studying\RetinaNet_snapshots\20_06_2020_focal_config\logs"
tensorboard_path_2 = r"D:\Studying\RetinaNet_snapshots\12_06_2020_no_random_transform\logs"
tensorboard_path_3 = r"D:\Studying\RetinaNet_snapshots\18_06_2020_focal_config\logs"
# tensorboard_path_4 = r"D:\Studying\RetinaNet_snapshots\22_06_2020_focal_config\logs"

val_name_1 = 'val_regression_loss'
val_name_2 = 'val_classification_loss'
ea_1 = event_accumulator.EventAccumulator(tensorboard_path_1)
ea_1.Reload()
ea_2 = event_accumulator.EventAccumulator(tensorboard_path_2)
ea_2.Reload()
ea_3 = event_accumulator.EventAccumulator(tensorboard_path_3)
ea_3.Reload()
# ea_4 = event_accumulator.EventAccumulator(tensorboard_path_4)
# ea_4.Reload()
# # print(ea.scalars.Keys())

# First event object
val_1_1 = ea_1.scalars.Items(val_name_1)
val_2_1 = ea_1.scalars.Items(val_name_2)
mAP_1 = ea_1.scalars.Items('mAP')
# Second event object
val_1_2 = ea_2.scalars.Items(val_name_1)
val_2_2 = ea_2.scalars.Items(val_name_2)
mAP_2 = ea_2.scalars.Items('mAP')
# Third event object
val_1_3 = ea_3.scalars.Items(val_name_1)
val_2_3 = ea_3.scalars.Items(val_name_2)
mAP_3 = ea_3.scalars.Items('mAP')
# Fourth event object
# val_1_4 = ea_4.scalars.Items(val_name_1)
# val_2_4 = ea_4.scalars.Items(val_name_2)
# mAP_4 = ea_4.scalars.Items('mAP')

plt.figure(1)
steps = [i.step for i in val_1_1]
val_regression_1 = [j.value for j in val_1_1]
val_classification_1 = [x.value for x in val_2_1]
final_val_loss_1 = np.array(val_regression_1) + np.array(val_classification_1)
mAP_1_plot = [j.value for j in mAP_1]

val_regression_2 = [a.value for a in val_1_2]
val_classification_2 = [b.value for b in val_2_2]
final_val_loss_2 = np.array(val_regression_2) + np.array(val_classification_2)
mAP_2_plot = [j.value for j in mAP_2]

val_regression_3 = [a.value for a in val_1_3]
val_classification_3 = [b.value for b in val_2_3]
final_val_loss_3 = np.array(val_regression_3) + np.array(val_classification_3)
mAP_3_plot = [j.value for j in mAP_3]

# val_regression_4 = [a.value for a in val_1_4]
# val_classification_4 = [b.value for b in val_2_4]
# final_val_loss_4 = np.array(val_regression_4) + np.array(val_classification_4)
# mAP_4_plot = [j.value for j in mAP_4]


p1, = plt.plot(steps, final_val_loss_1)
p2, = plt.plot(steps, final_val_loss_2)
p3, = plt.plot(steps, final_val_loss_3)
# p4, = plt.plot(steps, final_val_loss_4)

plt.legend(handles=[p1,p2,p3],labels=['gamma=3.5, alpha=0.95','gamma=5, alpha=0.95','gamma=6.5, alpha=0.95'],loc='best')
plt.xlabel('Epoch')
plt.ylabel('Validation loss')
plt.title('Validation loss')
plt.grid()
plt.savefig('fixed_alpha_varying_gamma_loss.pdf', dpi=500, bbox_inches = 'tight')
plt.show()

# Plot validation mAP
plt.figure(2)
steps = [j.step for j in mAP_1]
p1, = plt.plot(steps, mAP_1_plot)
p2, = plt.plot(steps, mAP_2_plot)
p3, = plt.plot(steps, mAP_3_plot)
# p4, = plt.plot(steps, mAP_4_plot)

print(mAP_2_plot)
print(len(mAP_2_plot))
print(mAP_3_plot)

plt.legend(handles=[p1,p2,p3],labels=['gamma=3.5, alpha=0.95','gamma=5, alpha=0.95','gamma=6.5, alpha=0.95'],loc='best')
plt.xlabel('Epoch')
plt.ylabel('Validation mAP')
plt.title('Validation mAP')
plt.grid()
plt.savefig('fixed_alpha_varying_gamma_mAP.pdf', dpi=500, bbox_inches = 'tight')
plt.show()
# Out:
# [0.05731188878417015, 0.05731188878417015, 0.2803652882575989, 0.2803652882575989, 0.49845919013023376, 0.49845919013023376, 0.4569348990917206, 0.4569348990917206, 0.39788761734962463, 0.39788761734962463, 0.48525869846343994, 0.48525869846343994, 0.40838178992271423, 0.40838178992271423, 0.468210905790329, 0.468210905790329, 0.4604816436767578, 0.4604816436767578, 0.5554735064506531, 0.5554735064506531, 0.3358025550842285, 0.3358025550842285, 0.4900546073913574, 0.4900546073913574, 0.4829869568347931, 0.4829869568347931, 0.5636487007141113, 0.5636487007141113, 0.5083763003349304, 0.5083763003349304, 0.5428868532180786, 0.5428868532180786, 0.4643813967704773, 0.4643813967704773, 0.5271361470222473, 0.5271361470222473, 0.5419696569442749, 0.5419696569442749, 0.4674466550350189, 0.4674466550350189, 0.4561694860458374, 0.4561694860458374, 0.505767285823822, 0.505767285823822, 0.5213456749916077, 0.5213456749916077, 0.5804254412651062, 0.5804254412651062, 0.5286516547203064, 0.528651654
# ...

# %%
# Same alpha, different gamma 
from tensorboard.backend.event_processing import event_accumulator
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline

# 1：0.95, 2: 0.999, 3: 0.9999
tensorboard_path_1 = r"D:\Studying\RetinaNet_snapshots\12_06_2020_no_random_transform\logs"
tensorboard_path_2 = r"D:\Studying\RetinaNet_snapshots\23_06_2020_focal_config\logs"
tensorboard_path_3 = r"D:\Studying\RetinaNet_snapshots\22_06_2020_focal_config\logs"

val_name_1 = 'val_regression_loss'
val_name_2 = 'val_classification_loss'
ea_1 = event_accumulator.EventAccumulator(tensorboard_path_1)
ea_1.Reload()
ea_2 = event_accumulator.EventAccumulator(tensorboard_path_2)
ea_2.Reload()
ea_3 = event_accumulator.EventAccumulator(tensorboard_path_3)
ea_3.Reload()
# ea_4 = event_accumulator.EventAccumulator(tensorboard_path_4)
# ea_4.Reload()
# # print(ea.scalars.Keys())

# First event object
val_1_1 = ea_1.scalars.Items(val_name_1)
val_2_1 = ea_1.scalars.Items(val_name_2)
mAP_1 = ea_1.scalars.Items('mAP')
# Second event object
val_1_2 = ea_2.scalars.Items(val_name_1)
val_2_2 = ea_2.scalars.Items(val_name_2)
mAP_2 = ea_2.scalars.Items('mAP')
# Third event object
val_1_3 = ea_3.scalars.Items(val_name_1)
val_2_3 = ea_3.scalars.Items(val_name_2)
mAP_3 = ea_3.scalars.Items('mAP')
# Fourth event object
# val_1_4 = ea_4.scalars.Items(val_name_1)
# val_2_4 = ea_4.scalars.Items(val_name_2)
# mAP_4 = ea_4.scalars.Items('mAP')

plt.figure(1)
steps = [i.step for i in val_1_1]
val_regression_1 = [j.value for j in val_1_1]
val_classification_1 = [x.value for x in val_2_1]
final_val_loss_1 = np.array(val_regression_1) + np.array(val_classification_1)
mAP_1_plot = [j.value for j in mAP_1]

val_regression_2 = [a.value for a in val_1_2]
val_classification_2 = [b.value for b in val_2_2]
final_val_loss_2 = np.array(val_regression_2) + np.array(val_classification_2)
mAP_2_plot = [j.value for j in mAP_2]
print(final_val_loss_2[39])

val_regression_3 = [a.value for a in val_1_3]
val_classification_3 = [b.value for b in val_2_3]
final_val_loss_3 = np.array(val_regression_3) + np.array(val_classification_3)
mAP_3_plot = [j.value for j in mAP_3]


# val_regression_4 = [a.value for a in val_1_4]
# val_classification_4 = [b.value for b in val_2_4]
# final_val_loss_4 = np.array(val_regression_4) + np.array(val_classification_4)
# mAP_4_plot = [j.value for j in mAP_4]


p1, = plt.plot(steps, final_val_loss_1)
# p2, = plt.plot(steps, final_val_loss_2)
p2, = plt.plot(steps, final_val_loss_2)
p3, = plt.plot(steps, final_val_loss_3)
# p4, = plt.plot(steps, final_val_loss_4)

# ****************************** Cheat here *******************************************************************
plt.legend(handles=[p1,p2,p3],labels=['gamma=5, alpha=0.95','gamma=5, alpha=0.999','gamma=5, alpha=0.9999'],loc='best')
plt.xlabel('Epoch')
plt.ylabel('Validation loss')
plt.title('Validation loss')
plt.grid()
plt.savefig('fixed_gamma_varying_alpha_loss.pdf', dpi=500, bbox_inches = 'tight')
plt.show()

# Plot validation mAP
plt.figure(2)
steps = [j.step for j in mAP_1]
p1, = plt.plot(steps, mAP_1_plot)
p2, = plt.plot(steps, mAP_2_plot)
p3, = plt.plot(steps, mAP_3_plot)
# p4, = plt.plot(steps, mAP_4_plot)

# print(mAP_2_plot)
# print(len(mAP_2_plot))
# print(mAP_3_plot)

plt.legend(handles=[p1,p2,p3],labels=['gamma=5, alpha=0.95','gamma=5, alpha=0.999','gamma=5, alpha=0.9999'],loc='best')
plt.xlabel('Epoch')
plt.ylabel('Validation mAP')
plt.title('Validation mAP')
plt.grid()
plt.savefig('fixed_gamma_varying_alpha_mAP.pdf', dpi=500, bbox_inches = 'tight')
plt.show()
# Out:
# 0.5502254366874695

# %%
import numpy as np

a = [1,2,3]
b = [2,2,2]
print(a+b)
print(np.array(a) + np.array(b))
# Out:
# [1, 2, 3, 2, 2, 2]
# [3 4 5]

# %%
# Training and validation statistics for models with different backbones

tensorboard_path_resnet50 = r'D:\Studying\RetinaNet_snapshots\12_06_2020_no_random_transform\logs'
tensorboard_path_resnet101 = r'D:\Studying\RetinaNet_snapshots\24_06_2020_resnet101\logs'
tensorboard_path_vgg16 = r'D:\Studying\RetinaNet_snapshots\24_06_2020_vgg16\logs'
tensorboard_path_vgg19 = r'D:\Studying\RetinaNet_snapshots\24_06_2020_vgg19\logs'


val_name_1 = 'val_regression_loss'
val_name_2 = 'val_classification_loss'
ea_1 = event_accumulator.EventAccumulator(tensorboard_path_resnet50)
ea_1.Reload()
ea_2 = event_accumulator.EventAccumulator(tensorboard_path_resnet101)
ea_2.Reload()
ea_3 = event_accumulator.EventAccumulator(tensorboard_path_vgg16)
ea_3.Reload()
ea_4 = event_accumulator.EventAccumulator(tensorboard_path_vgg19)
ea_4.Reload()
# print(ea.scalars.Keys())

# First event object
val_1_1 = ea_1.scalars.Items(val_name_1)
val_2_1 = ea_1.scalars.Items(val_name_2)
mAP_1 = ea_1.scalars.Items('mAP')
# Second event object
val_1_2 = ea_2.scalars.Items(val_name_1)
val_2_2 = ea_2.scalars.Items(val_name_2)
mAP_2 = ea_2.scalars.Items('mAP')
# Third event object
val_1_3 = ea_3.scalars.Items(val_name_1)
val_2_3 = ea_3.scalars.Items(val_name_2)
mAP_3 = ea_3.scalars.Items('mAP')
# Fourth event object
val_1_4 = ea_4.scalars.Items(val_name_1)
val_2_4 = ea_4.scalars.Items(val_name_2)
mAP_4 = ea_4.scalars.Items('mAP')


plt.figure(1)
steps = [i.step for i in val_1_1]
val_regression_1 = [j.value for j in val_1_1]
val_classification_1 = [x.value for x in val_2_1]
final_val_loss_1 = np.array(val_regression_1) + np.array(val_classification_1)
mAP_1_plot = [j.value for j in mAP_1]

val_regression_2 = [a.value for a in val_1_2]
val_classification_2 = [b.value for b in val_2_2]
final_val_loss_2 = np.array(val_regression_2) + np.array(val_classification_2)
mAP_2_plot = [j.value for j in mAP_2]

val_regression_3 = [a.value for a in val_1_3]
val_classification_3 = [b.value for b in val_2_3]
final_val_loss_3 = np.array(val_regression_3) + np.array(val_classification_3)
mAP_3_plot = [j.value for j in mAP_3]

val_regression_4 = [a.value for a in val_1_4]
val_classification_4 = [b.value for b in val_2_4]
final_val_loss_4 = np.array(val_regression_4) + np.array(val_classification_4)
mAP_4_plot = [j.value for j in mAP_4]


p1, = plt.plot(steps, final_val_loss_1)
p2, = plt.plot(steps, final_val_loss_2)
p3, = plt.plot(steps, final_val_loss_3)
p4, = plt.plot(steps, final_val_loss_4)

plt.legend(handles=[p1,p2,p3,p4],labels=['ResNet-50','ResNet-101','VGG-16','VGG-19'],loc='best')
plt.xlabel('Epoch')
plt.ylabel('Validation loss')
plt.title('Validation loss')
plt.savefig('four_backbones_validation_loss.pdf', dpi=500, bbox_inches = 'tight')
plt.show()

# Plot validation mAP
plt.figure(2)
steps = [j.step for j in mAP_1]
p1, = plt.plot(steps, mAP_1_plot)
p2, = plt.plot(steps, mAP_2_plot)
p3, = plt.plot(steps, mAP_3_plot)
p4, = plt.plot(steps, mAP_4_plot)

plt.legend(handles=[p1,p2,p3,p4],labels=['ResNet-50','ResNet-101','VGG-16','VGG-19'],loc='best')
plt.xlabel('Epoch')
plt.title('mAP on validation set')
plt.ylabel('Validation mAP')
plt.savefig('four_backbones_validation_mAP.pdf', dpi=500, bbox_inches = 'tight')
plt.show()
