# %%
import numpy as np

test = np.zeros((0,))
for i in range(5):
    test = np.append(test,1)
    
print(test)
test = np.cumsum(test)
print(test)
# Out:
# [1. 1. 1. 1. 1.]
# [1. 2. 3. 4. 5.]

# %%
import cv2
import pydicom as dicom
from matplotlib import pyplot as plt

path= r'D:\Studying\RetinaNet_Project\all_DICOM_files\AllDICOMs\22614522_2dec4948fbe6336d_MG_L_CC_ANON.dcm'
dicom_data = dicom.dcmread(path).pixel_array

cv2.rectangle(dicom_data, (154, 324),(342, 529), (255,0,0), -1)
plt.imshow(dicom_data, cmap='gray')
