# %%
import numpy as np
import cv2 
from PIL import Image

img_1 = cv2.imread('000000008021.jpg')
print(type(img_1))
# img_2 = Image.open('000000008021.jpg')
img_2 = Image.open('000000008021.jpg').convert('RGB')
print(type(img_2))
img_3 = np.asarray(img_2)
print(type(img_3))
img_3
# Out:
# <class 'numpy.ndarray'>
# <class 'PIL.Image.Image'>
# <class 'numpy.ndarray'>
# array([[[12,  2,  0],
#         [17,  7,  5],
#         [14,  3,  1],
#         ...,
#         [33, 16, 24],
#         [25,  5, 14],
#         [27,  8, 14]],
#
#        [[15,  5,  3],
#         [14,  4,  2],
#         [22, 11,  9],
#         ...,
#         [23,  6, 14],
#         [19,  2,  8],
#         [31, 14, 20]],
#
#        [[15,  5,  4],
#         [15,  5,  4],
#         [15,  3,  3],
#         ...,
#         [23,  8, 13],
#         [23,  6, 12],
#         [32, 15, 21]],
#
#        ...,
#
#        [[ 7,  2,  0],
#         [ 9,  4,  0],
#         [11,  6,  2],
#         ...,
#         [15,  1,  1],
#         [17,  3,  3],
#         [21,  7,  7]],
#
#        [[ 9,  5,  2],
#         [ 9,  5,  2],
#         [ 8,  3,  0],
#         ...,
#         [14,  2,  2],
#         [20,  8,  8],
#         [18,  6,  6]],
#
#        [[12,  8,  7],
#         [ 4,  0,  0],
#         [10,  5,  2],
#         ...,
#         [14,  2,  2],
#         [14,  2,  2],
#         [16,  4,  4]]], dtype=uint8)

# %%
import numpy as np
import cv2 
from PIL import Image
import matplotlib.pyplot as plt

# The result returned by cv2.imread is in BGR colour space
img_1 = cv2.imread('000000008021.jpg')
print(type(img_1))
# Deep copy
img_2 = img_1.copy()
# Convert from BGR colour space to RGB colour space
img_2 = cv2.cvtColor(img_2, cv2.COLOR_BGR2RGB)
plt.subplot2grid((1,2), (0,0))
plt.imshow(img_1)
plt.subplot2grid((1,2), (0,1))
plt.imshow(img_2)
# Out:
# <class 'numpy.ndarray'>

# %%
import numpy as np
import cv2 
from PIL import Image
from matplotlib import pyplot as plt

img_1 = Image.open('000000008021.jpg').convert('RGB')
img_2 = np.asarray(img_1)
# Deep copy
img_3 = img_2.copy()
img_3 = cv2.cvtColor(img_3, cv2.COLOR_RGB2BGR)
# img_3 = cv2.cvtColor(img_3, cv2.COLOR_BGR2RGB)
img_3

# plt.show
plt.subplot2grid((1,2), (0,0))
# plt.imshow(img_1)
plt.imshow(img_2)
plt.subplot2grid((1,2), (0,1))
plt.imshow(img_3)

# %%
import numpy as np
import cv2 
from PIL import Image
from matplotlib import pyplot as plt

img_1 = Image.open('000000008021.jpg')
img_1

from matplotlib import pyplot as plt
# colspan tells the number of grids(in column) you want your current subplot to take up.
# rowspan tells the number of grids(in row) you want your current subplot to take up.
plt.subplot2grid((3, 3), (0, 2), colspan = 2)
plt.subplot2grid((3, 3), (0, 1), colspan = 1)
plt.subplot2grid((3, 3), (0, 0), colspan = 1)
plt.subplot2grid((3, 3), (1, 0), rowspan = 2, colspan = 2)
# plt.subplot2grid((3, 3), (0, 1), colspan = 2)
# plt.subplot2grid((3, 3), (2, 1), colspan = 2)

import numpy as np
x = np.array([[[[1,2,1]]]])
print(x.shape)
print(x)
print('*******************')
y = np.expand_dims(x, axis=0)#expand_dims(a, axis)就是在axis的那一个轴上把数据加上去
print(y.shape)
print(y)
# print('*******************')
# n = np.expand_dims(x, axis=1)
# print(n.shape) 
# print(n)


import numpy as np
import cv2 
from PIL import Image
from matplotlib import pyplot as plt

img_1 = Image.open('000000008021.jpg').convert('RGB')
img_2 = np.asarray(img_1)
print(img_2.shape)
print(img_2[1,1,0])
img_2 = np.expand_dims(img_2, axis = 0)
print(img_2.shape)
print(img_2[0,1,1,0])

import numpy as np
test = np.array([[[1,2,1], [2,2,3], [3,1,4]], [[3,1,4], [3,6,7], [1,4,1]]])
print(test.shape)
test_2 = test[:, :, ::-1].copy()
test_2
